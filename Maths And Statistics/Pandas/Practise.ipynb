# %%
import pandas as pd

# %%
df = pd.read_csv("./1_intro/movies.csv")

# %%
df.head()
# Out:
#                                          title   industry  release_year  \
# 0                              Pather Panchali  Bollywood          1955
# 1  Doctor Strange in the Multiverse of Madness  Hollywood          2022
# 2                        Thor: The Dark World   Hollywood          2013
# 3                              Thor: Ragnarok   Hollywood          2017
# 4                      Thor: Love and Thunder   Hollywood          2022
#
#    imdb_rating                     studio   budget   revenue       unit  \
# 0          8.3  Government of West Bengal  70000.0  100000.0  Thousands
# 1          7.0             Marvel Studios    200.0     954.8   Millions
# 2          6.8             Marvel Studios    165.0     644.8   Millions
# 3          7.9             Marvel Studios    180.0     854.0   Millions
# 4          6.8             Marvel Studios    250.0     670.0   Millions
#
#   currency language
# 0      INR  Bengali
# 1      USD  English
# 2      USD  English
# ...

# %%
df.tail()
# Out:
#                         title   industry  release_year  imdb_rating  \
# 32                  Shershaah  Bollywood          2021          8.4
# 33           K.G.F: Chapter 2  Bollywood          2022          8.4
# 34  Pushpa: The Rise - Part 1  Bollywood          2021          7.6
# 35                        RRR  Bollywood          2022          8.0
# 36   Baahubali: The Beginning  Bollywood          2015          8.0
#
#                  studio  budget  revenue      unit currency language
# 32   Dharma Productions   500.0    950.0  Millions      INR    Hindi
# 33        Hombale Films     1.0     12.5  Billions      INR  Kannada
# 34  Mythri Movie Makers     2.0      3.6  Billions      INR   Telugu
# 35    DVV Entertainment     5.5     12.0  Billions      INR   Telugu
# 36     Arka Media Works     1.8      6.5  Billions      INR   Telugu

# %%
df.sample(5)
# Out:
#                                   title   industry  release_year  imdb_rating  \
# 29                    The Kashmir Files  Bollywood          2022          8.3
# 20  Captain America: The Winter Soldier  Hollywood          2014          7.8
# 17                    Avengers: Endgame  Hollywood          2019          8.4
# 18               Avengers: Infinity War  Hollywood          2018          8.4
# 16                             Parasite  Hollywood          2019          8.5
#
#             studio  budget  revenue      unit currency language
# 29     Zee Studios   250.0   3409.0  Millions      INR    Hindi
# 20  Marvel Studios   177.0    714.4  Millions      USD  English
# 17  Marvel Studios   400.0   2798.0  Millions      USD  English
# 18  Marvel Studios   400.0   2048.0  Millions      USD  English
# 16             NaN    15.5    263.1  Millions      USD  English

# %%
df.language.unique()
# Out:
# array(['Bengali', 'English', 'Hindi', 'Kannada', 'Telugu'], dtype=object)

# %%
df.language.value_counts()
# Out:
# language
# English    20
# Hindi      12
# Telugu      3
# Bengali     1
# Kannada     1
# Name: count, dtype: int64

# %%
df.head()
# Out:
#                                          title   industry  release_year  \
# 0                              Pather Panchali  Bollywood          1955
# 1  Doctor Strange in the Multiverse of Madness  Hollywood          2022
# 2                        Thor: The Dark World   Hollywood          2013
# 3                              Thor: Ragnarok   Hollywood          2017
# 4                      Thor: Love and Thunder   Hollywood          2022
#
#    imdb_rating                     studio   budget   revenue       unit  \
# 0          8.3  Government of West Bengal  70000.0  100000.0  Thousands
# 1          7.0             Marvel Studios    200.0     954.8   Millions
# 2          6.8             Marvel Studios    165.0     644.8   Millions
# 3          7.9             Marvel Studios    180.0     854.0   Millions
# 4          6.8             Marvel Studios    250.0     670.0   Millions
#
#   currency language
# 0      INR  Bengali
# 1      USD  English
# 2      USD  English
# ...

# %%
df["profit"] = df.apply(lambda x: x["revenue"] - x["budget"],axis=1)
df.head()
# Out:
#                                          title   industry  release_year  \
# 0                              Pather Panchali  Bollywood          1955
# 1  Doctor Strange in the Multiverse of Madness  Hollywood          2022
# 2                        Thor: The Dark World   Hollywood          2013
# 3                              Thor: Ragnarok   Hollywood          2017
# 4                      Thor: Love and Thunder   Hollywood          2022
#
#    imdb_rating                     studio   budget   revenue       unit  \
# 0          8.3  Government of West Bengal  70000.0  100000.0  Thousands
# 1          7.0             Marvel Studios    200.0     954.8   Millions
# 2          6.8             Marvel Studios    165.0     644.8   Millions
# 3          7.9             Marvel Studios    180.0     854.0   Millions
# 4          6.8             Marvel Studios    250.0     670.0   Millions
#
#   currency language   profit
# 0      INR  Bengali  30000.0
# 1      USD  English    754.8
# ...

# %%
df["age"] = df["release_year"].apply(lambda x: 2024 - x)
df.head()
# Out:
#                                          title   industry  release_year  \
# 0                              Pather Panchali  Bollywood          1955
# 1  Doctor Strange in the Multiverse of Madness  Hollywood          2022
# 2                        Thor: The Dark World   Hollywood          2013
# 3                              Thor: Ragnarok   Hollywood          2017
# 4                      Thor: Love and Thunder   Hollywood          2022
#
#    imdb_rating                     studio   budget   revenue       unit  \
# 0          8.3  Government of West Bengal  70000.0  100000.0  Thousands
# 1          7.0             Marvel Studios    200.0     954.8   Millions
# 2          6.8             Marvel Studios    165.0     644.8   Millions
# 3          7.9             Marvel Studios    180.0     854.0   Millions
# 4          6.8             Marvel Studios    250.0     670.0   Millions
#
#   currency language   profit  age
# 0      INR  Bengali  30000.0   69
# ...

# %%
df.describe()
# Out:
#        release_year  imdb_rating        budget        revenue        profit  \
# count     37.000000    36.000000     37.000000      37.000000     37.000000
# mean    2007.027027     7.919444   2084.975135    4117.135135   2032.160000
# std       17.657995     1.204947  11477.487145   16372.462682   5199.733731
# min     1946.000000     1.900000      1.000000       3.100000      0.120000
# 25%     2001.000000     7.800000     15.500000     263.100000    153.900000
# 50%     2014.000000     8.100000    165.000000     701.800000    479.800000
# 75%     2018.000000     8.400000    250.000000    2000.000000   1600.000000
# max     2022.000000     9.300000  70000.000000  100000.000000  30000.000000
#
#              age
# count  37.000000
# mean   16.972973
# std    17.657995
# min     2.000000
# 25%     6.000000
# 50%    10.000000
# 75%    23.000000
# max    78.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 37 entries, 0 to 36
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   title         37 non-null     object
#  1   industry      37 non-null     object
#  2   release_year  37 non-null     int64
#  3   imdb_rating   36 non-null     float64
#  4   studio        34 non-null     object
#  5   budget        37 non-null     float64
#  6   revenue       37 non-null     float64
#  7   unit          37 non-null     object
#  8   currency      37 non-null     object
#  9   language      37 non-null     object
#  10  profit        37 non-null     float64
#  11  age           37 non-null     int64
# dtypes: float64(4), int64(2), object(6)
# memory usage: 3.6+ KB

# %%
df[(df.release_year>=2000) & (df.release_year<=2006)]
# Out:
#                        title   industry  release_year  imdb_rating  \
# 7   The Pursuit of Happyness  Hollywood          2006          8.0
# 8                  Gladiator  Hollywood          2000          8.5
# 23  Kabhi Khushi Kabhie Gham  Bollywood          2001          7.4
# 26       Munna Bhai M.B.B.S.  Bollywood          2003          8.1
#
#                       studio  budget  revenue      unit currency language  \
# 7          Columbia Pictures    55.0    307.1  Millions      USD  English
# 8       Universal Pictures     103.0    460.5  Millions      USD  English
# 23        Dharma Productions   390.0   1360.0  Millions      INR    Hindi
# 26  Vinod Chopra Productions   100.0    410.0  Millions      INR    Hindi
#
#     profit  age
# 7    252.1   18
# 8    357.5   24
# 23   970.0   23
# 26   310.0   21

# %%
df.drop(8,inplace=True)
df
# Out:
#                                           title   industry  release_year  \
# 0                               Pather Panchali  Bollywood          1955
# 1   Doctor Strange in the Multiverse of Madness  Hollywood          2022
# 2                         Thor: The Dark World   Hollywood          2013
# 3                               Thor: Ragnarok   Hollywood          2017
# 4                       Thor: Love and Thunder   Hollywood          2022
# 5                      The Shawshank Redemption  Hollywood          1994
# 6                                  Interstellar  Hollywood          2014
# 7                      The Pursuit of Happyness  Hollywood          2006
# 9                                       Titanic  Hollywood          1997
# 10                        It's a Wonderful Life  Hollywood          1946
# 11                                       Avatar  Hollywood          2009
# 12                                The Godfather  Hollywood          1972
# ...

# %%
df.iloc[35]
# Out:
# index                                 36
# title           Baahubali: The Beginning
# industry                       Bollywood
# release_year                        2015
# imdb_rating                          8.0
# studio                  Arka Media Works
# budget                               1.8
# revenue                              6.5
# unit                            Billions
# currency                             INR
# language                          Telugu
# profit                               4.7
# age                                    9
# Name: 35, dtype: object

# %%
df.loc[2]
# Out:
# index                               2
# title           Thor: The Dark World
# industry                    Hollywood
# release_year                     2013
# imdb_rating                       6.8
# studio                 Marvel Studios
# budget                          165.0
# revenue                         644.8
# unit                         Millions
# currency                          USD
# language                      English
# profit                          479.8
# age                                11
# Name: 2, dtype: object

# %%
df.reset_index(inplace=True)
df
# Out:
#     index                                        title   industry  \
# 0       0                              Pather Panchali  Bollywood
# 1       1  Doctor Strange in the Multiverse of Madness  Hollywood
# 2       2                        Thor: The Dark World   Hollywood
# 3       3                              Thor: Ragnarok   Hollywood
# 4       4                      Thor: Love and Thunder   Hollywood
# 5       5                     The Shawshank Redemption  Hollywood
# 6       6                                 Interstellar  Hollywood
# 7       7                     The Pursuit of Happyness  Hollywood
# 8       9                                      Titanic  Hollywood
# 9      10                        It's a Wonderful Life  Hollywood
# 10     11                                       Avatar  Hollywood
# 11     12                                The Godfather  Hollywood
# 12     13                              The Dark Knight  Hollywood
# ...

# %%
dataset = [900,1100,1200,1450,800,1000,1650]
mean=1000
std=100

# %%
zscore = [(i-mean)/std for i in dataset]
zscore
# Out:
# [-1.0, 1.0, 2.0, 4.5, -2.0, 0.0, 6.5]

# %%
outliers = [i for i in zscore if (i<-3) or (i>3)]
outliers
# Out:
# [4.5, 6.5]
